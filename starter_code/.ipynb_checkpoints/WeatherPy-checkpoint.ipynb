# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'

city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
temp = []
wind_speed = []


for city in cities:
    try:
        query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=imperial"
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        temp.append(weather_json['main']['temp'])
        humidity.append(weather_json['main']['humidity'])
        cloudiness.append(weather_json['clouds']['all'])
        wind_speed.append(weather_json['wind']['speed'])
        city_name.append(city)
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        print(f'Processing Record {cities.index(city)} | {city}')
    except:
        print("City not found.")
# Out:
# Processing Record 0 | bethel
# Processing Record 1 | bathsheba
# Processing Record 2 | lithgow
# Processing Record 3 | hilo
# Processing Record 4 | tabou
# Processing Record 5 | carnarvon
# Processing Record 6 | chiungutwa
# Processing Record 7 | albany
# Processing Record 8 | tual
# Processing Record 9 | sioux falls
# Processing Record 10 | qaanaaq
# Processing Record 11 | ushuaia
# Processing Record 12 | sisimiut
# Processing Record 13 | pevek
# Processing Record 14 | port keats
# Processing Record 15 | avarua
# Processing Record 16 | asau
# Processing Record 17 | tiksi
# Processing Record 18 | bambous virieux
# Processing Record 19 | rikitea
# Processing Record 20 | chuy
# Processing Record 21 | victoria
# Processing Record 22 | puerto cabezas
# Processing Record 23 | atuona
# Processing Record 24 | bredasdorp
# City not found.
# Processing Record 26 | port hardy
# Processing Record 27 | tsimlyansk
# Processing Record 28 | okhotsk
# Processing Record 29 | padang
# Processing Record 30 | ito
# Processing Record 31 | sakakah
# Processing Record 32 | talnakh
# Processing Record 33 | alta floresta
# Processing Record 34 | punta arenas
# Processing Record 35 | ishurdi
# Processing Record 36 | tautira
# Processing Record 37 | beyneu
# Processing Record 38 | cape town
# Processing Record 39 | peniche
# Processing Record 40 | thompson
# Processing Record 41 | butaritari
# Processing Record 42 | narodychi
# Processing Record 43 | pisco
# Processing Record 44 | ponta do sol
# Processing Record 45 | falmouth
# Processing Record 46 | shache
# Processing Record 47 | saint-philippe
# Processing Record 48 | hachinohe
# Processing Record 49 | kavieng
# Processing Record 50 | westport
# Processing Record 51 | clyde river
# Processing Record 52 | farmington
# Processing Record 53 | hamilton
# Processing Record 54 | port alfred
# Processing Record 55 | sangueya
# Processing Record 56 | kapaa
# Processing Record 57 | hermanus
# Processing Record 58 | channel-port aux basques
# Processing Record 59 | povorino
# Processing Record 60 | chokurdakh
# Processing Record 61 | lebu
# Processing Record 62 | new norfolk
# City not found.
# Processing Record 64 | cherskiy
# Processing Record 65 | sobolevo
# Processing Record 66 | ostrovnoy
# Processing Record 67 | sola
# Processing Record 68 | lenti
# Processing Record 69 | huarmey
# Processing Record 70 | hays
# Processing Record 71 | iquique
# Processing Record 72 | port elizabeth
# Processing Record 73 | arraial do cabo
# Processing Record 74 | japura
# Processing Record 75 | havoysund
# Processing Record 76 | souillac
# Processing Record 77 | lubango
# Processing Record 78 | campbell river
# Processing Record 79 | jamestown
# City not found.
# Processing Record 81 | falam
# Processing Record 82 | labuhan
# Processing Record 83 | saint-augustin
# City not found.
# Processing Record 85 | winnemucca
# Processing Record 86 | elban
# Processing Record 87 | fortuna
# Processing Record 88 | mariental
# Processing Record 89 | uruacu
# Processing Record 90 | wagar
# Processing Record 91 | kholodnyy
# Processing Record 92 | spring valley
# Processing Record 93 | dikson
# City not found.
# Processing Record 95 | taoudenni
# Processing Record 96 | east london
# Processing Record 97 | dubbo
# Processing Record 98 | jinka
# Processing Record 99 | nikolskoye
# Processing Record 100 | klaksvik
# Processing Record 101 | mataura
# Processing Record 102 | muhos
# Processing Record 103 | chiautla
# Processing Record 104 | tecoanapa
# Processing Record 105 | kaitangata
# Processing Record 106 | georgetown
# Processing Record 107 | rawson
# Processing Record 108 | dehloran
# Processing Record 109 | necochea
# Processing Record 110 | lavrentiya
# Processing Record 111 | grand-santi
# Processing Record 112 | bonthe
# Processing Record 113 | ribeira grande
# Processing Record 114 | tevaitoa
# City not found.
# Processing Record 116 | bluff
# Processing Record 117 | potsdam
# Processing Record 118 | portland
# Processing Record 119 | solnechnyy
# Processing Record 120 | sao joao da barra
# Processing Record 121 | kruisfontein
# Processing Record 122 | nouadhibou
# Processing Record 123 | atambua
# Processing Record 124 | mayen
# Processing Record 125 | cuamba
# City not found.
# Processing Record 127 | ust-nera
# Processing Record 128 | waipawa
# Processing Record 129 | port lincoln
# Processing Record 130 | lagoa
# City not found.
# Processing Record 132 | tuktoyaktuk
# Processing Record 133 | te anau
# Processing Record 134 | bonavista
# Processing Record 135 | mutare
# Processing Record 136 | svetlyy
# Processing Record 137 | ukiah
# Processing Record 138 | biak
# Processing Record 139 | nyaunglebin
# Processing Record 140 | fort morgan
# City not found.
# Processing Record 142 | takoradi
# Processing Record 143 | tasiilaq
# Processing Record 144 | new iberia
# Processing Record 145 | adre
# Processing Record 146 | grindavik
# City not found.
# Processing Record 148 | bengkulu
# Processing Record 149 | golden
# Processing Record 150 | barrow
# Processing Record 151 | hithadhoo
# Processing Record 152 | aksha
# Processing Record 153 | faya
# Processing Record 154 | bereda
# Processing Record 155 | makaryev
# Processing Record 156 | madang
# Processing Record 157 | camacha
# Processing Record 158 | sovetskiy
# Processing Record 159 | bilma
# Processing Record 160 | dennery
# Processing Record 161 | bambanglipuro
# Processing Record 162 | vaini
# Processing Record 163 | bara
# Processing Record 164 | esterhazy
# Processing Record 165 | druzhba
# Processing Record 166 | hobyo
# Processing Record 167 | pangnirtung
# Processing Record 168 | komsomolskiy
# Processing Record 169 | puerto ayora
# City not found.
# City not found.
# Processing Record 172 | geraldton
# Processing Record 173 | montepuez
# Processing Record 174 | ancud
# Processing Record 175 | hasaki
# Processing Record 176 | deputatskiy
# Processing Record 177 | baley
# Processing Record 178 | vila franca do campo
# Processing Record 179 | sinnamary
# Processing Record 180 | sancti spiritus
# Processing Record 181 | codrington
# Processing Record 182 | nanortalik
# Processing Record 183 | huai thalaeng
# Processing Record 184 | vallenar
# Processing Record 185 | sao filipe
# City not found.
# Processing Record 187 | gisborne
# Processing Record 188 | yellowknife
# Processing Record 189 | salalah
# Processing Record 190 | leningradskiy
# Processing Record 191 | provideniya
# Processing Record 192 | vanimo
# Processing Record 193 | keti bandar
# Processing Record 194 | mahebourg
# Processing Record 195 | manggar
# City not found.
# Processing Record 197 | gravdal
# Processing Record 198 | hambantota
# Processing Record 199 | margate
# Processing Record 200 | flinders
# Processing Record 201 | praia da vitoria
# Processing Record 202 | esperance
# Processing Record 203 | huayucachi
# Processing Record 204 | kalianget
# Processing Record 205 | iqaluit
# Processing Record 206 | constitucion
# Processing Record 207 | poya
# Processing Record 208 | kloulklubed
# Processing Record 209 | saskylakh
# Processing Record 210 | konevo
# Processing Record 211 | castro
# Processing Record 212 | vostok
# Processing Record 213 | bandar-e lengeh
# Processing Record 214 | itoigawa
# Processing Record 215 | cabo san lucas
# Processing Record 216 | dongkan
# Processing Record 217 | meulaboh
# Processing Record 218 | nemuro
# Processing Record 219 | kodiak
# Processing Record 220 | vila velha
# City not found.
# Processing Record 222 | plettenberg bay
# City not found.
# Processing Record 224 | ruteng
# Processing Record 225 | khatanga
# Processing Record 226 | kidal
# City not found.
# Processing Record 228 | coquimbo
# Processing Record 229 | broken hill
# Processing Record 230 | muzhi
# Processing Record 231 | shenjiamen
# Processing Record 232 | upernavik
# Processing Record 233 | kinkala
# Processing Record 234 | comodoro rivadavia
# Processing Record 235 | torbay
# Processing Record 236 | tabuk
# Processing Record 237 | myingyan
# Processing Record 238 | busselton
# City not found.
# Processing Record 240 | ailigandi
# Processing Record 241 | hobart
# Processing Record 242 | tuatapere
# Processing Record 243 | juegang
# Processing Record 244 | san jose de guanipa
# Processing Record 245 | bondo
# Processing Record 246 | xuanwu
# Processing Record 247 | sitka
# Processing Record 248 | anadyr
# Processing Record 249 | katherine
# City not found.
# City not found.
# Processing Record 252 | mouila
# Processing Record 253 | mairang
# Processing Record 254 | saint-leu
# Processing Record 255 | lompoc
# Processing Record 256 | touros
# Processing Record 257 | poum
# Processing Record 258 | ranong
# Processing Record 259 | noumea
# Processing Record 260 | alofi
# Processing Record 261 | sinop
# Processing Record 262 | quatre cocos
# Processing Record 263 | eureka
# Processing Record 264 | smithers
# Processing Record 265 | santa cruz
# Processing Record 266 | nome
# Processing Record 267 | beli potok
# Processing Record 268 | severo-kurilsk
# Processing Record 269 | bandarbeyla
# Processing Record 270 | port-gentil
# Processing Record 271 | gaspe
# City not found.
# Processing Record 273 | mar del plata
# Processing Record 274 | rapid valley
# Processing Record 275 | krasnoselkup
# Processing Record 276 | alihe
# Processing Record 277 | ankang
# Processing Record 278 | san quintin
# Processing Record 279 | stephenville
# Processing Record 280 | nago
# Processing Record 281 | syracuse
# Processing Record 282 | huesca
# Processing Record 283 | tahoua
# Processing Record 284 | manuk mangkaw
# Processing Record 285 | faanui
# Processing Record 286 | xinzhi
# Processing Record 287 | terra santa
# Processing Record 288 | linda
# Processing Record 289 | napanee
# Processing Record 290 | bulgan
# Processing Record 291 | saint anthony
# Processing Record 292 | hervey bay
# Processing Record 293 | dustlik
# Processing Record 294 | viamao
# Processing Record 295 | skibbereen
# Processing Record 296 | perry hall
# Processing Record 297 | belyy yar
# Processing Record 298 | xilagani
# Processing Record 299 | sumenep
# Processing Record 300 | la paz
# Processing Record 301 | djambala
# Processing Record 302 | alice springs
# City not found.
# Processing Record 304 | nioro
# Processing Record 305 | piacabucu
# Processing Record 306 | luderitz
# City not found.
# Processing Record 308 | jinxiang
# Processing Record 309 | gazanjyk
# Processing Record 310 | shorapur
# Processing Record 311 | sangar
# Processing Record 312 | aviles
# Processing Record 313 | nishihara
# Processing Record 314 | coahuayana
# Processing Record 315 | coromoro
# Processing Record 316 | kirakira
# Processing Record 317 | pontal do parana
# City not found.
# Processing Record 319 | ranfurly
# City not found.
# Processing Record 321 | scottsbluff
# Processing Record 322 | saint george
# Processing Record 323 | siverek
# City not found.
# Processing Record 325 | srednekolymsk
# Processing Record 326 | wanaka
# Processing Record 327 | tomatlan
# Processing Record 328 | tougan
# Processing Record 329 | chupa
# City not found.
# Processing Record 331 | adrar
# Processing Record 332 | ishigaki
# Processing Record 333 | havre-saint-pierre
# Processing Record 334 | carballo
# Processing Record 335 | husavik
# Processing Record 336 | berlevag
# City not found.
# Processing Record 338 | andenes
# Processing Record 339 | lorengau
# Processing Record 340 | longyearbyen
# Processing Record 341 | mookane
# Processing Record 342 | hit
# Processing Record 343 | ouesso
# Processing Record 344 | airai
# Processing Record 345 | paamiut
# City not found.
# Processing Record 347 | kresna
# Processing Record 348 | langsa
# Processing Record 349 | kayerkan
# City not found.
# Processing Record 351 | hovd
# Processing Record 352 | teknaf
# Processing Record 353 | mount gambier
# Processing Record 354 | jamalteca
# Processing Record 355 | chongwe
# Processing Record 356 | villa carlos paz
# Processing Record 357 | narsaq
# Processing Record 358 | kununurra
# Processing Record 359 | sambava
# Processing Record 360 | araouane
# Processing Record 361 | mecca
# Processing Record 362 | van buren
# Processing Record 363 | nieves
# Processing Record 364 | teahupoo
# Processing Record 365 | marystown
# Processing Record 366 | polson
# Processing Record 367 | thurso
# Processing Record 368 | puri
# Processing Record 369 | kaeo
# Processing Record 370 | la romana
# Processing Record 371 | isangel
# City not found.
# Processing Record 373 | qeshm
# Processing Record 374 | sao francisco de paula
# Processing Record 375 | asmara
# Processing Record 376 | fougeres
# Processing Record 377 | dingle
# Processing Record 378 | talkha
# Processing Record 379 | marsh harbour
# Processing Record 380 | byron bay
# Processing Record 381 | katsuura
# Processing Record 382 | itarema
# Processing Record 383 | grand gaube
# Processing Record 384 | osorno
# Processing Record 385 | ossora
# Processing Record 386 | nicoya
# Processing Record 387 | sur
# Processing Record 388 | chulman
# Processing Record 389 | aleksandrov gay
# Processing Record 390 | kutum
# Processing Record 391 | grahamstown
# Processing Record 392 | matara
# Processing Record 393 | vardo
# Processing Record 394 | lixourion
# Processing Record 395 | porto nacional
# Processing Record 396 | salima
# Processing Record 397 | brae
# Processing Record 398 | norman wells
# Processing Record 399 | chimbote
# Processing Record 400 | tyukhtet
# Processing Record 401 | prieska
# Processing Record 402 | shellbrook
# City not found.
# Processing Record 404 | maragogi
# Processing Record 405 | san carlos de bariloche
# Processing Record 406 | ahipara
# Processing Record 407 | sorland
# Processing Record 408 | bantry
# Processing Record 409 | hearst
# Processing Record 410 | urumqi
# Processing Record 411 | arlit
# Processing Record 412 | roald
# Processing Record 413 | brynmawr
# Processing Record 414 | cathedral city
# Processing Record 415 | lowestoft
# Processing Record 416 | broome
# Processing Record 417 | priargunsk
# Processing Record 418 | huangcun
# Processing Record 419 | guayabetal
# Processing Record 420 | richards bay
# Processing Record 421 | shimoda
# Processing Record 422 | poso
# Processing Record 423 | mayo
# Processing Record 424 | pashiya
# City not found.
# Processing Record 426 | meiktila
# Processing Record 427 | la ronge
# Processing Record 428 | fare
# Processing Record 429 | nuuk
# Processing Record 430 | kaduy
# Processing Record 431 | beringovskiy
# Processing Record 432 | orlik
# Processing Record 433 | pueblo bello
# Processing Record 434 | tapes
# Processing Record 435 | shu
# Processing Record 436 | mount isa
# Processing Record 437 | boyuibe
# Processing Record 438 | lipin bor
# Processing Record 439 | lugovoy
# Processing Record 440 | aklavik
# Processing Record 441 | tuy hoa
# Processing Record 442 | kavaratti
# Processing Record 443 | chagoda
# Processing Record 444 | buraydah
# Processing Record 445 | severnoye
# Processing Record 446 | wad rawah
# Processing Record 447 | changli
# Processing Record 448 | wilmington
# Processing Record 449 | tessalit
# Processing Record 450 | sylvan lake
# Processing Record 451 | kamenka
# Processing Record 452 | caidian
# Processing Record 453 | mareeba
# Processing Record 454 | banbury
# Processing Record 455 | soe
# Processing Record 456 | nhulunbuy
# Processing Record 457 | solton
# Processing Record 458 | dunedin
# Processing Record 459 | bintulu
# Processing Record 460 | rockford
# Processing Record 461 | port blair
# Processing Record 462 | khani
# Processing Record 463 | tefe
# Processing Record 464 | sidney
# Processing Record 465 | khorixas
# Processing Record 466 | rio gallegos
# Processing Record 467 | ustye
# Processing Record 468 | maneadero
# Processing Record 469 | champerico
# Processing Record 470 | dezful
# Processing Record 471 | mezen
# Processing Record 472 | acapulco
# Processing Record 473 | pacocha
# Processing Record 474 | hua hin
# Processing Record 475 | kishorganj
# Processing Record 476 | saldanha
# Processing Record 477 | coolum beach
# Processing Record 478 | khasan
# Processing Record 479 | murwillumbah
# Processing Record 480 | cadiz
# Processing Record 481 | amnat charoen
# Processing Record 482 | nizhniy kuranakh
# Processing Record 483 | manzanillo
# Processing Record 484 | eirunepe
# Processing Record 485 | valdez
# Processing Record 486 | dwarka
# City not found.
# City not found.
# Processing Record 489 | tura
# Processing Record 490 | arica
# Processing Record 491 | koumac
# City not found.
# Processing Record 493 | portoferraio
# Processing Record 494 | tilichiki
# Processing Record 495 | petropavl
# Processing Record 496 | tshikapa
# Processing Record 497 | marawi
# Processing Record 498 | ayame
# Processing Record 499 | cap malheureux
# City not found.
# Processing Record 501 | port-cartier
# Processing Record 502 | susanville
# Processing Record 503 | yeppoon
# Processing Record 504 | aksu
# Processing Record 505 | pomerode
# City not found.
# Processing Record 507 | boca do acre
# Processing Record 508 | yima
# Processing Record 509 | los llanos de aridane
# Processing Record 510 | namibe
# Processing Record 511 | muros
# Processing Record 512 | uvira
# Processing Record 513 | rawicz
# Processing Record 514 | daulatpur
# Processing Record 515 | rancho palos verdes
# Processing Record 516 | belaya gora
# Processing Record 517 | ixtapa
# Processing Record 518 | tashtyp
# Processing Record 519 | castelo
# Processing Record 520 | gat
# Processing Record 521 | rorvik
# Processing Record 522 | bayonet point
# Processing Record 523 | hanyang
# Processing Record 524 | aksarka
# Processing Record 525 | turba
# Processing Record 526 | parkersburg
# Processing Record 527 | morton
# Processing Record 528 | tymovskoye
# Processing Record 529 | cowra
# Processing Record 530 | toora-khem
# Processing Record 531 | avinurme
# Processing Record 532 | mpika
# Processing Record 533 | corcoran
# Processing Record 534 | olinda
# Processing Record 535 | mogadishu
# Processing Record 536 | limoges
# Processing Record 537 | cody
# Processing Record 538 | lesnoy
# Processing Record 539 | kisangani
# Processing Record 540 | jijiga
# Processing Record 541 | presidencia roque saenz pena
# Processing Record 542 | abrau-dyurso
# Processing Record 543 | knysna
# Processing Record 544 | blanquefort
# Processing Record 545 | olafsvik
# Processing Record 546 | belmonte
# Processing Record 547 | hastings
# Processing Record 548 | sao jose da coroa grande
# Processing Record 549 | iberia
# Processing Record 550 | sabla
# Processing Record 551 | dinghai
# Processing Record 552 | yulara
# Processing Record 553 | taltal
# Processing Record 554 | innisfail
# Processing Record 555 | port augusta
# Processing Record 556 | matveyevka
# Processing Record 557 | dalaba
# Processing Record 558 | salinas
# Processing Record 559 | mufulira
# City not found.
# Processing Record 561 | kapoeta
# Processing Record 562 | kansanshi
# Processing Record 563 | harper
# Processing Record 564 | baiyin
# Processing Record 565 | hargeysa
# Processing Record 566 | dobretu
# Processing Record 567 | rio tercero
# Processing Record 568 | naze
# Processing Record 569 | camacupa
# Processing Record 570 | chicama
# Processing Record 571 | halifax
# Processing Record 572 | kodinsk
# Processing Record 573 | kuznechnoye
# Processing Record 574 | ambilobe
# Processing Record 575 | yanggu
# Processing Record 576 | zakamensk
# Processing Record 577 | krasnoznamensk
# Processing Record 578 | wajima
# Processing Record 579 | payakumbuh
# Processing Record 580 | choix
# Processing Record 581 | hlotse
# Processing Record 582 | boyabat
# Processing Record 583 | boda
# Processing Record 584 | ushtobe
# Processing Record 585 | bronnitsy
# Processing Record 586 | porto novo
# Processing Record 587 | holeby
# Processing Record 588 | cidreira
# Processing Record 589 | meadow lake
# Processing Record 590 | axim
# Processing Record 591 | kalas
# City not found.
# City not found.
# Processing Record 594 | awjilah
# Processing Record 595 | the valley
# Processing Record 596 | medicine hat
# Processing Record 597 | bridgewater
# Processing Record 598 | vestmannaeyjar
# Processing Record 599 | viedma
# Processing Record 600 | fairbanks
# Processing Record 601 | itaituba
# City not found.
# Processing Record 603 | umm kaddadah
# Processing Record 604 | akdepe
# Processing Record 605 | garden city
# Processing Record 606 | yicheng
# Processing Record 607 | atyrau
# Processing Record 608 | alugan
# Processing Record 609 | mana
# City not found.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": city_name, "Cloudiness": cloudiness, "Country": country, "Date": date,
                           "Humidity": humidity, "Latitude": lat, "Longitude": lng, "Temperature": temp,
                           "Wind Speed": wind_speed})

weather_df.to_csv('cities.csv')

weather_df.head(5)
# Out:
#         City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0     bethel           1      US  1588117403        25     41.37     -73.41
# 1  bathsheba          75      BB  1588117403        83     13.22     -59.52
# 2    lithgow          90      AU  1588117403        88    -33.48     150.15
# 3       hilo          20      US  1588117298        58     19.73    -155.09
# 4      tabou          97      CI  1588117404        85      4.42      -7.35
#
#    Temperature  Wind Speed
# 0        58.19        4.70
# 1        78.80       14.99
# 2        67.21       10.29
# 3        78.44       12.75
# 4        80.58        5.84

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Temperature"], color = 'blue', marker = 'o', edgecolor = 'black', alpha = ".5")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temp (F)")
plt.title("City Latitude vs Temperature") 
plt.show()
plt.savefig("lat_temp.png")

# %%
#Temperatures increase the closer a city is to the equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], color = 'blue', marker = 'o', edgecolor = 'black', alpha = ".5")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitude vs Humidity") 
plt.show()
plt.savefig("lat_humidity.png")

# %%
#Cities closer to the equator more consistently have high humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], color = 'blue', marker = 'o', edgecolor = 'black', alpha = ".5")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs Cloudiness") 
plt.show()
plt.savefig("lat_cloudiness.png")

# %%
#There is no discernable connection between latitude and cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], color = 'blue', marker = 'o', edgecolor = 'black', alpha = ".5")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed") 
plt.show()
plt.savefig("lat_wind")

# %%
#Wind speed and latitude do not appear to be correlated.
